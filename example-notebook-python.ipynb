# %% [markdown]
# # Example Notebook in Python
#
# https://github.com/plasmabio/template-python

# %% [markdown]
# ## Numpy and Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(np.linspace(0, 20, 100)), color="orange");

# %% [markdown]
# ## Available modules

# %%
# %load_ext watermark
# %watermark --python --watermark
# %watermark --packages numpy,scipy,pandas,matplotlib,seaborn,Bio,jupyterlab,ipywidgets
# Out:
# Python implementation: CPython
# Python version       : 3.10.5
# IPython version      : 8.4.0
#
# Watermark: 2.3.1
#
# numpy     : 1.23.0
# scipy     : 1.8.1
# pandas    : 1.4.3
# matplotlib: 3.5.2
# seaborn   : 0.11.2
# Bio       : 1.79
# jupyterlab: 3.4.3
# ipywidgets: 7.7.1
